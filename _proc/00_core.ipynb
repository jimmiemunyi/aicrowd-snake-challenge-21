# %% [raw]
# ---
# description: The core functions and variables that I use a lot in the notebook.
# output-file: core.html
# title: core
#
# ---

# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->

# %% [markdown]
# Placed here to avoid a lot of repetition.

# %%
import pandas as pd
from the_snake_project.core import *

# %% [markdown]
# ## Variables

# %%
ds_path = '../../dataset/ai-crowd-snake-dataset/'

# %%
ds = Path(ds_path)
Path.BASE_PATH = ds

# %% [markdown]
# ## Functions

# %%
#| echo: false
#| output: asis
show_doc(get_species)
# Out:
# ---
#
# [source](https://github.com/jimmiemunyi/the-snake-project/blob/main/the_snake_project/core.py#L21){target="_blank" style="float:right; font-size:smaller"}
#
# ### get_species
#
# >      get_species (row)
#
# Add a species column in the series
#
# |    | **Type** | **Details** |
# | -- | -------- | ----------- |
# | row |  | pandas dataframe row. |
# | **Returns** | **Series** | **pandas dataframe series** |

# %%
#| echo: false
#| output: asis
show_doc(get_x)
# Out:
# ---
#
# [source](https://github.com/jimmiemunyi/the-snake-project/blob/main/the_snake_project/core.py#L29){target="_blank" style="float:right; font-size:smaller"}
#
# ### get_x
#
# >      get_x (r)
#
# Returns the image path

# %%
#| echo: false
#| output: asis
show_doc(get_y_gns)
# Out:
# ---
#
# [source](https://github.com/jimmiemunyi/the-snake-project/blob/main/the_snake_project/core.py#L36){target="_blank" style="float:right; font-size:smaller"}
#
# ### get_y_gns
#
# >      get_y_gns (r)
#
# Get the label y - Only the genus

# %%
#| echo: false
#| output: asis
show_doc(get_dls)
# Out:
# ---
#
# [source](https://github.com/jimmiemunyi/the-snake-project/blob/main/the_snake_project/core.py#L41){target="_blank" style="float:right; font-size:smaller"}
#
# ### get_dls
#
# >      get_dls (df, get_x, get_y, item_tfms, batch_tfms=None)

# %% [markdown]
# #### Example
