# %% [raw]
# ---
# description: The core functions and variables that I use a lot in the notebook.
# output-file: core.html
# title: core
#
# ---

# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->

# %% [markdown]
# Placed here to avoid a lot of repetition.

# %%
import pandas as pd
from the_snake_project.core import *

# %% [markdown]
# ## Variables

# %%
ds_path = '../dataset/ai-crowd-snake-dataset/'

# %% [markdown]
# ## Functions

# %%
#| echo: false
#| output: asis
show_doc(get_species)
# Out:
# ---
#
# [source](https://github.com/jimmiemunyi/the-snake-project/blob/main/the_snake_project/core.py#L13){target="_blank" style="float:right; font-size:smaller"}
#
# ### get_species
#
# >      get_species (row)
#
# Add a species column in the series
#
# |    | **Type** | **Details** |
# | -- | -------- | ----------- |
# | row |  | pandas dataframe row. |
# | **Returns** | **Series** | **pandas dataframe series** |

# %% [markdown]
# #### Example
